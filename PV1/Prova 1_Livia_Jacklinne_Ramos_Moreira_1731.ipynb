# %% [markdown]
# # Prova 1 - C210 - L5/L6
#
# ### Instruções
# * Esta prova contém 3 questões sobre, respectivamente, Machine Learning, Algoritmos genéticos e PSO, cada uma pode possuir itens definidos por letras (a, b, c...)
# * Esta prova deve ser feita INDIVIDUALMENTE, sem acesso a outros alunos
# * É permitido o acesso SOMENTE aos códigos disponibilizados no Github da disciplina: https://github.com/Antonio-AV/C210_IA
# * Para a realização da prova apenas altere este notebook
# * Coloque seu nome completo como nome do notebook ao enviar
# * Ao final, envie na tarefa criada no Teams apenas o notebook com as alterações
# * Preencha o campo a seguir com suas informações
#
# #### Boa prova!!!

# %% [markdown]
# ##### Nome: Livia Jacklinne Ramos Moreira
# ##### Curso: GEC
# ##### Matrícula: 1731

# %% [markdown]
# ## 1- Machine Learning
#
# Utilizando a função make_blobs apresentada em sala, crie um conjunto de dados que conte com 300 amostras, 2 características, com o número de centros igual ao último número de sua matrícula, por exemplo: matrícula = 98 -> n° de centros = 8, (caso o último número de sua matrícula seja 0 ou 1, utilize 5 como número de centros), espalhamento dos dados = 0.5 e com embaralhamento.
#
# Após a criação do conjunto, utilize do método Kmeans para realizar o agrupamento (clusterização) desses dados, passando como número de grupos o próprio número de centros definido anteriormente com o auxílio de sua matícula,  e por fim mostre gráficamente como ficaram esses grupos e seus respectivos centros.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import calinski_harabasz_score, silhouette_score

# %%
# Criando dados usando a função make blobs (Parametros são: n° de amostras, n° de características, n° de centros,
# espalhamento dos dados, e embaralhamento dos dados)

data, labels = make_blobs(n_samples=300, n_features=2, centers=5, cluster_std=0.5, shuffle=True)
print(data)
# Out:
# [[ 5.39783806e+00 -2.31749426e-02]
#  [ 6.10928139e+00 -3.53031060e-01]
#  [-4.16910997e+00  1.05247945e+01]
#  [-3.78988230e+00  5.82970948e+00]
#  [ 4.88325518e+00  1.31473412e-01]
#  [-4.39526334e+00  1.00432808e+01]
#  [-3.25998548e+00  5.31204967e+00]
#  [-4.16676975e+00  9.45650352e+00]
#  [-3.02142291e+00  5.11003952e+00]
#  [-5.84688039e+00  9.95159008e+00]
#  [-4.75604148e+00  4.62781751e+00]
#  [-4.83027562e+00  9.24679858e+00]
#  [-3.42711941e+00  6.15282610e+00]
#  [-4.67895639e+00  9.24335137e+00]
#  [ 3.99981669e+00  5.91903225e+00]
#  [-4.49308038e+00  4.87707053e+00]
#  [ 4.79528630e+00  6.22805288e+00]
#  [-4.31650280e+00  9.71751682e+00]
#  [ 4.86007896e+00 -6.39045139e-01]
#  [-5.19638336e+00  4.88548882e+00]
#  [-5.30635452e+00  4.85470120e+00]
#  [ 5.69384399e+00 -5.32581521e-01]
#  [-4.26521158e+00  6.08773722e+00]
#  [-5.38853833e+00  4.26106886e+00]
#  [-4.80133778e+00  4.51542467e+00]
#  [-4.17192042e+00  6.61162017e+00]
#  [-3.28130081e+00  5.25506110e+00]
#  [-3.35618996e+00  5.23582651e+00]
#  [-3.19169798e+00  5.39735634e+00]
#  [-4.49691074e+00  5.48432214e+00]
#  [ 4.58193877e+00  6.82054984e+00]
#  [-4.44824217e+00  9.08982816e+00]
#  [ 4.75010639e+00  7.19389315e+00]
#  [ 5.19680137e+00  6.75385756e+00]
#  [ 5.07007858e+00  4.58539311e-01]
#  [-4.90882578e+00  4.42655333e+00]
#  [-2.09816229e+00  6.37280997e+00]
#  [ 3.69633477e+00  6.09724225e+00]
#  [ 4.90141131e+00 -6.45243408e-02]
#  [-3.17626528e+00  5.41043352e+00]
#  [ 3.56448539e+00  6.75067874e+00]
#  [-4.34244180e+00  4.67433348e+00]
#  [-5.30718291e+00  4.94694444e+00]
#  [-3.69797204e+00  5.67025868e+00]
#  [-4.07562077e+00  4.70468753e+00]
#  [ 5.17169573e+00 -1.16571509e+00]
#  [ 4.64046299e+00  6.53952165e+00]
#  [-2.82504817e+00  5.32931031e+00]]

# %%
plt.rcParams['figure.dpi'] = 150
plt.scatter(data[:, 0], data[:, 1], marker="o", edgecolors="black")
plt.show()

# %%
modelo = KMeans(n_clusters=5)
modelo.fit(data)
# Out:
# C:\Users\livia\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5)

# %%
# Prevendo os valores dos dados
resposta = modelo.predict(data)


# Separando os grupos de acordo com o que o modelo previu
grupo_1 = data[resposta == 0]
grupo_2 = data[resposta == 1]
grupo_3 = data[resposta == 2]
grupo_4 = data[resposta == 3]
grupo_5 = data[resposta == 4]
centros = modelo.cluster_centers_

# %%
plt.scatter(grupo_1[:, 0], grupo_1[:, 1], c="green", marker="s", label="Grupo 1", edgecolors="black")
plt.scatter(grupo_2[:, 0], grupo_2[:, 1], c="blue", marker="o", label="Grupo 2", edgecolors="black")
plt.scatter(grupo_3[:, 0], grupo_3[:, 1], c="red", marker="v", label="Grupo 3", edgecolors="black")
plt.scatter(grupo_4[:, 0], grupo_4[:, 1], c="pink", marker="v", label="Grupo 4", edgecolors="black")
plt.scatter(grupo_5[:, 0], grupo_5[:, 1], c="yellow", marker="v", label="Grupo 5", edgecolors="black")
plt.scatter(centros[:, 0], centros[:, 1], c="orange", label="Centros", marker="*")

plt.legend(scatterpoints=1)

plt.show()

# %% [markdown]
# ## 2- Algoritmos genéticos

# %%
import random
import numpy as np
############################################ BITSET ############################################
class BitSet:
    def __init__(self, size):
        self.bits = np.full((1, size), False)

    def get(self, index):
        return self.bits[0, index]

    def set(self, index, value):
        self.bits[0, index] = value

    def flip(self, index):
        self.bits[0, index] = not self.bits[0, index]

    def debug(self):
        print(self.bits)
        
############################################ CROMOSSOMO ############################################
class Chromossome:
    def __init__(self, x = None, y = None):
        if x == None:
            x = random.randint(-15, 15)

        if y == None:
            y = random.randint(-15, 15)

        self.__genes = Chromossome.get_genotype(x, y)

    def get_genes(self):
        return self.__genes

    def set_genes(self, genes):
        self.__genes = genes

    def to_string(self):
        chr_str = "G = ["

        for i in range(10):
            chr_str += (i == 5 and " " or "") + (self.__genes.get(i) and "1" or "0")

        x, y = Chromossome.get_fenotype(self.__genes)

        chr_str += "], F = [" + str(x) + ", " + str(y) + "]"

        return chr_str

    @staticmethod
    def get_genotype(x, y):
        bits = BitSet(10)

        xy_binary = "{:05b}".format(x) + "{:05b}".format(y)

        for i in range(10):
            bits.set(i, xy_binary[i] == '1')

        return bits

    @staticmethod
    def get_fenotype(genes):
        x = (8 * genes.get(0) +
            4 * genes.get(1) +
            2 * genes.get(2) +
            1 * genes.get(3))

        if (genes.get(4) == 1):
            x *= -1

        y = (8 * genes.get(5) +
            4 * genes.get(6) +
            2 * genes.get(7) +
            1 * genes.get(8))

        if (genes.get(9) == 1):
            y *= -1

        return x, y
    
############################################ PROBLEMA ############################################
class Problem:

    @staticmethod
    def f(x, y):
        return x**2 + y**2

    @staticmethod
    def f_chromossome(chromossome):
        x, y = Chromossome.get_fenotype(chromossome.get_genes())
        return Problem.f(x, y)

    @staticmethod
    def g(x, y):
        return 1 / (1 + Problem.f(x, y))

    @staticmethod
    def g_chromossome(chromossome):
        x, y = Chromossome.get_fenotype(chromossome.get_genes())
        return Problem.g(x, y)

    @staticmethod
    def f_average(population):
        avg = 0
        for chromossome in population:
            avg += Problem.f_chromossome(chromossome)
        avg /= len(population)
        return avg

    @staticmethod
    def g_average(population):
        avg = 0
        for chromossome in population:
            avg += Problem.g_chromossome(chromossome)
        avg /= len(population)
        return avg
    
############################################ UTILITÁRIOS ############################################
class GeneticUtils:

    @staticmethod
    def find_best_chromossome(population):
        best_chromossome = None

        for chromossome in population:
            score = Problem.g_chromossome(chromossome)

            if best_chromossome is None or score > Problem.g_chromossome(best_chromossome):
                best_chromossome = chromossome

        return best_chromossome

    @staticmethod
    def find_worst_chromossome(population):
        worst_chromossome = None

        for chromossome in population:
            score = Problem.g_chromossome(chromossome)

            if worst_chromossome is None or score < Problem.g_chromossome(worst_chromossome):
                worst_chromossome = chromossome

        return worst_chromossome

    @staticmethod
    def format_chromossome(chromossome):
        return f"{chromossome.to_string()}, Score = {Problem.g_chromossome(chromossome):.3f}"

# %%
############################################ OPERADORES GENÉTICOS ############################################
class GeneticOperators:

    MUTATION_PROBABILITY = 0.05

    @staticmethod
    def selection(population):
        parent1 = random.choice(population)
        parent2 = random.choice(population)

        print(f"1st parent chosen for crossover: {GeneticUtils.format_chromossome(parent1)}")
        print(f"2nd parent chosen for crossover: {GeneticUtils.format_chromossome(parent2)}")

        return parent1, parent2

    @staticmethod
    def crossover(population, parent1, parent2):
        crossover_point = random.randint(1, 9)
        print(f"Crossover will happen at point {crossover_point}")

        parent1_genes = parent1.get_genes()
        parent2_genes = parent2.get_genes()

        child1_genes = BitSet(10)
        child2_genes = BitSet(10)

        for i in range(crossover_point):
            child1_genes.set(i, parent1_genes.get(i))
            child2_genes.set(i, parent2_genes.get(i))

        for i in range(crossover_point, 10):
            child1_genes.set(i, parent2_genes.get(i))
            child2_genes.set(i, parent1_genes.get(i))

        child1 = Chromossome()
        child1.set_genes(child1_genes)
        print(f"1st child generated from crossover: {GeneticUtils.format_chromossome(child1)}")

        child2 = Chromossome()
        child2.set_genes(child2_genes)
        print(f"2nd child generated from crossover: {GeneticUtils.format_chromossome(child2)}")
        
        population.append(child1)
        population.append(child2)
        
    @staticmethod
    def mutation(population):
        prob = random.uniform(0, 1)

        if prob >= GeneticOperators.MUTATION_PROBABILITY:
            return

        target = random.choice(population)

        mutation_point = random.randint(0, 9)
        print(f"Individual {target.to_string()} will mutate at point {mutation_point}")

        genes = target.get_genes()
        genes.flip(mutation_point)

        print(f"Individual {target.to_string()} mutated at point {mutation_point}")

    @staticmethod
    def elitism(population):
        for _ in range(2):
            worst_individual = GeneticUtils.find_worst_chromossome(population)
            print(f"Removing worst individual from population: {GeneticUtils.format_chromossome(worst_individual)}")
            population.remove(worst_individual)

# %%
############################################ MAIN ############################################
if __name__ == "__main__":
    population = []
    for _ in range(30):
        population.append(Chromossome())

    generation = 0
    population_score = Problem.g_average(population)


    while generation < 50:
        parent1, parent2 = GeneticOperators.selection(population)

        GeneticOperators.crossover(population, parent1, parent2)
        GeneticOperators.mutation(population)
        GeneticOperators.elitism(population)

        generation += 1
        population_score = Problem.g_average(population)


        print(f"Generation # {generation} -> Average population score = {population_score:.3f}\n")

    best_chromossome = GeneticUtils.find_best_chromossome(population)
    print(f"Best individual: {GeneticUtils.format_chromossome(best_chromossome)}")
# Out:
# 1st parent chosen for crossover: G = [00111 01111], F = [-3, -7], Score = 0.017
# 2nd parent chosen for crossover: G = [00011 00110], F = [-1, 3], Score = 0.091
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00111 00110], F = [-3, 3], Score = 0.053
# 2nd child generated from crossover: G = [00011 01111], F = [-1, -7], Score = 0.020
# Removing worst individual from population: G = [01111 01110], F = [-7, 7], Score = 0.010
# Removing worst individual from population: G = [01110 01101], F = [7, -6], Score = 0.012
# Generation # 1 -> Average population score = 0.065
#
# 1st parent chosen for crossover: G = [00011 00110], F = [-1, 3], Score = 0.091
# 2nd parent chosen for crossover: G = [01011 01010], F = [-5, 5], Score = 0.020
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00011 00110], F = [-1, 3], Score = 0.091
# 2nd child generated from crossover: G = [01011 01010], F = [-5, 5], Score = 0.020
# Removing worst individual from population: G = [01110 01101], F = [7, -6], Score = 0.012
# Removing worst individual from population: G = [01000 01110], F = [4, 7], Score = 0.015
# Generation # 2 -> Average population score = 0.067
#
# 1st parent chosen for crossover: G = [01010 00010], F = [5, 1], Score = 0.037
# 2nd parent chosen for crossover: G = [00111 01111], F = [-3, -7], Score = 0.017
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00111 01111], F = [-3, -7], Score = 0.017
# 2nd child generated from crossover: G = [01010 00010], F = [5, 1], Score = 0.037
# Removing worst individual from population: G = [01110 00111], F = [7, -3], Score = 0.017
# Removing worst individual from population: G = [00111 01111], F = [-3, -7], Score = 0.017
# Generation # 3 -> Average population score = 0.068
#
# 1st parent chosen for crossover: G = [00100 01010], F = [2, 5], Score = 0.033
# 2nd parent chosen for crossover: G = [00011 01010], F = [-1, 5], Score = 0.037
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00100 01010], F = [2, 5], Score = 0.033
# 2nd child generated from crossover: G = [00011 01010], F = [-1, 5], Score = 0.037
# Removing worst individual from population: G = [00111 01110], F = [-3, 7], Score = 0.017
# Removing worst individual from population: G = [00111 01111], F = [-3, -7], Score = 0.017
# Generation # 4 -> Average population score = 0.069
#
# 1st parent chosen for crossover: G = [00110 01010], F = [3, 5], Score = 0.029
# 2nd parent chosen for crossover: G = [00011 01111], F = [-1, -7], Score = 0.020
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00111 01111], F = [-3, -7], Score = 0.017
# 2nd child generated from crossover: G = [00010 01010], F = [1, 5], Score = 0.037
# Removing worst individual from population: G = [00111 01111], F = [-3, -7], Score = 0.017
# Removing worst individual from population: G = [00100 01111], F = [2, -7], Score = 0.019
# Generation # 5 -> Average population score = 0.070
#
# 1st parent chosen for crossover: G = [00100 01111], F = [2, -7], Score = 0.019
# 2nd parent chosen for crossover: G = [00101 00010], F = [-2, 1], Score = 0.167
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00100 00010], F = [2, 1], Score = 0.167
# 2nd child generated from crossover: G = [00101 01111], F = [-2, -7], Score = 0.019
# Removing worst individual from population: G = [00100 01111], F = [2, -7], Score = 0.019
# Removing worst individual from population: G = [00100 01111], F = [2, -7], Score = 0.019
# Generation # 6 -> Average population score = 0.075
#
# 1st parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# 2nd parent chosen for crossover: G = [00010 01010], F = [1, 5], Score = 0.037
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00010 01010], F = [1, 5], Score = 0.037
# 2nd child generated from crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# Removing worst individual from population: G = [00101 01111], F = [-2, -7], Score = 0.019
# Removing worst individual from population: G = [01011 01010], F = [-5, 5], Score = 0.020
# Generation # 7 -> Average population score = 0.078
#
# 1st parent chosen for crossover: G = [00001 01100], F = [0, 6], Score = 0.027
# 2nd parent chosen for crossover: G = [00011 00110], F = [-1, 3], Score = 0.091
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00001 00110], F = [0, 3], Score = 0.100
# 2nd child generated from crossover: G = [00011 01100], F = [-1, 6], Score = 0.026
# Removing worst individual from population: G = [00011 01111], F = [-1, -7], Score = 0.020
# Removing worst individual from population: G = [00011 01111], F = [-1, -7], Score = 0.020
# Generation # 8 -> Average population score = 0.081
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 01010], F = [1, 5], Score = 0.037
# Crossover will happen at point 8
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 01010], F = [1, 5], Score = 0.037
# Removing worst individual from population: G = [01011 01010], F = [-5, 5], Score = 0.020
# Removing worst individual from population: G = [01000 01010], F = [4, 5], Score = 0.024
# Generation # 9 -> Average population score = 0.092
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 01010], F = [-1, 5], Score = 0.037
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00011 01010], F = [-1, 5], Score = 0.037
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [01100 00101], F = [6, -2], Score = 0.024
# Removing worst individual from population: G = [00011 01100], F = [-1, 6], Score = 0.026
# Generation # 10 -> Average population score = 0.102
#
# 1st parent chosen for crossover: G = [00111 00010], F = [-3, 1], Score = 0.091
# 2nd parent chosen for crossover: G = [00001 00110], F = [0, 3], Score = 0.100
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00111 00110], F = [-3, 3], Score = 0.053
# 2nd child generated from crossover: G = [00001 00010], F = [0, 1], Score = 0.500
# Individual G = [01010 00010], F = [5, 1] will mutate at point 2
# Individual G = [01110 00010], F = [7, 1] mutated at point 2
# Removing worst individual from population: G = [01110 00010], F = [7, 1], Score = 0.020
# Removing worst individual from population: G = [00011 01100], F = [-1, 6], Score = 0.026
# Generation # 11 -> Average population score = 0.119
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 01010], F = [1, 5], Score = 0.037
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 01011], F = [1, -5], Score = 0.037
# Removing worst individual from population: G = [00001 01100], F = [0, 6], Score = 0.027
# Removing worst individual from population: G = [00110 01010], F = [3, 5], Score = 0.029
# Generation # 12 -> Average population score = 0.129
#
# 1st parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00100 01010], F = [2, 5], Score = 0.033
# Crossover will happen at point 4
# 1st child generated from crossover: G = [00010 01010], F = [1, 5], Score = 0.037
# 2nd child generated from crossover: G = [00100 00010], F = [2, 1], Score = 0.167
# Removing worst individual from population: G = [00100 01010], F = [2, 5], Score = 0.033
# Removing worst individual from population: G = [00100 01010], F = [2, 5], Score = 0.033
# Generation # 13 -> Average population score = 0.134
#
# 1st parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# 2nd parent chosen for crossover: G = [00001 00110], F = [0, 3], Score = 0.100
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00010 00110], F = [1, 3], Score = 0.091
# 2nd child generated from crossover: G = [00001 00111], F = [0, -3], Score = 0.100
# Removing worst individual from population: G = [00011 01010], F = [-1, 5], Score = 0.037
# Removing worst individual from population: G = [01010 00010], F = [5, 1], Score = 0.037
# Generation # 14 -> Average population score = 0.138
#
# 1st parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Individual G = [00010 00010], F = [1, 1] will mutate at point 2
# Individual G = [00110 00010], F = [3, 1] mutated at point 2
# Removing worst individual from population: G = [00011 01010], F = [-1, 5], Score = 0.037
# Removing worst individual from population: G = [00010 01010], F = [1, 5], Score = 0.037
# Generation # 15 -> Average population score = 0.149
#
# 1st parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# 2nd parent chosen for crossover: G = [00001 00010], F = [0, 1], Score = 0.500
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00001 00111], F = [0, -3], Score = 0.100
# Removing worst individual from population: G = [00010 01010], F = [1, 5], Score = 0.037
# Removing worst individual from population: G = [00010 01010], F = [1, 5], Score = 0.037
# Generation # 16 -> Average population score = 0.161
#
# 1st parent chosen for crossover: G = [00111 00110], F = [-3, 3], Score = 0.053
# 2nd parent chosen for crossover: G = [00001 00111], F = [0, -3], Score = 0.100
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00101 00111], F = [-2, -3], Score = 0.071
# 2nd child generated from crossover: G = [00011 00110], F = [-1, 3], Score = 0.091
# Removing worst individual from population: G = [00011 01010], F = [-1, 5], Score = 0.037
# Removing worst individual from population: G = [00010 01011], F = [1, -5], Score = 0.037
# Generation # 17 -> Average population score = 0.164
#
# 1st parent chosen for crossover: G = [01000 00011], F = [4, -1], Score = 0.056
# 2nd parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# Crossover will happen at point 6
# 1st child generated from crossover: G = [01000 00111], F = [4, -3], Score = 0.038
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 01010], F = [1, 5], Score = 0.037
# Removing worst individual from population: G = [01010 00001], F = [5, 0], Score = 0.038
# Generation # 18 -> Average population score = 0.174
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Individual G = [00010 00011], F = [1, -1] will mutate at point 2
# Individual G = [00110 00011], F = [3, -1] mutated at point 2
# Removing worst individual from population: G = [01000 00111], F = [4, -3], Score = 0.038
# Removing worst individual from population: G = [00111 00110], F = [-3, 3], Score = 0.053
# Generation # 19 -> Average population score = 0.185
#
# 1st parent chosen for crossover: G = [01000 00001], F = [4, 0], Score = 0.059
# 2nd parent chosen for crossover: G = [01000 00011], F = [4, -1], Score = 0.056
# Crossover will happen at point 5
# 1st child generated from crossover: G = [01000 00011], F = [4, -1], Score = 0.056
# 2nd child generated from crossover: G = [01000 00001], F = [4, 0], Score = 0.059
# Removing worst individual from population: G = [00111 00110], F = [-3, 3], Score = 0.053
# Removing worst individual from population: G = [01000 00011], F = [4, -1], Score = 0.056
# Generation # 20 -> Average population score = 0.185
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [01000 00011], F = [4, -1], Score = 0.056
# Removing worst individual from population: G = [01000 00001], F = [4, 0], Score = 0.059
# Generation # 21 -> Average population score = 0.196
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [01000 00001], F = [4, 0], Score = 0.059
# Removing worst individual from population: G = [00101 00111], F = [-2, -3], Score = 0.071
# Generation # 22 -> Average population score = 0.206
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Individual G = [00001 00010], F = [0, 1] will mutate at point 1
# Individual G = [01001 00010], F = [-4, 1] mutated at point 1
# Removing worst individual from population: G = [01001 00010], F = [-4, 1], Score = 0.056
# Removing worst individual from population: G = [00111 00010], F = [-3, 1], Score = 0.091
# Generation # 23 -> Average population score = 0.208
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00011 00110], F = [-1, 3], Score = 0.091
# Removing worst individual from population: G = [00110 00011], F = [3, -1], Score = 0.091
# Generation # 24 -> Average population score = 0.224
#
# 1st parent chosen for crossover: G = [00011 00110], F = [-1, 3], Score = 0.091
# 2nd parent chosen for crossover: G = [00101 00000], F = [-2, 0], Score = 0.200
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00101 00000], F = [-2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00011 00110], F = [-1, 3], Score = 0.091
# Removing worst individual from population: G = [00010 00111], F = [1, -3], Score = 0.091
# Removing worst individual from population: G = [00011 00110], F = [-1, 3], Score = 0.091
# Generation # 25 -> Average population score = 0.228
#
# 1st parent chosen for crossover: G = [00010 00110], F = [1, 3], Score = 0.091
# 2nd parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# Crossover will happen at point 4
# 1st child generated from crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# 2nd child generated from crossover: G = [00010 00110], F = [1, 3], Score = 0.091
# Removing worst individual from population: G = [00010 00111], F = [1, -3], Score = 0.091
# Removing worst individual from population: G = [00010 00110], F = [1, 3], Score = 0.091
# Generation # 26 -> Average population score = 0.228
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00001 00111], F = [0, -3], Score = 0.100
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00001 00111], F = [0, -3], Score = 0.100
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00110 00010], F = [3, 1], Score = 0.091
# Removing worst individual from population: G = [00011 00110], F = [-1, 3], Score = 0.091
# Generation # 27 -> Average population score = 0.236
#
# 1st parent chosen for crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# 2nd parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# Removing worst individual from population: G = [00010 00111], F = [1, -3], Score = 0.091
# Removing worst individual from population: G = [00010 00111], F = [1, -3], Score = 0.091
# Generation # 28 -> Average population score = 0.244
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00001 00111], F = [0, -3], Score = 0.100
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00001 00110], F = [0, 3], Score = 0.100
# Removing worst individual from population: G = [00011 00110], F = [-1, 3], Score = 0.091
# Removing worst individual from population: G = [00010 00111], F = [1, -3], Score = 0.091
# Generation # 29 -> Average population score = 0.253
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00101 00000], F = [-2, 0], Score = 0.200
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00101 00000], F = [-2, 0], Score = 0.200
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 00110], F = [1, 3], Score = 0.091
# Removing worst individual from population: G = [00010 00111], F = [1, -3], Score = 0.091
# Generation # 30 -> Average population score = 0.264
#
# 1st parent chosen for crossover: G = [00001 00111], F = [0, -3], Score = 0.100
# 2nd parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Crossover will happen at point 5
# 1st child generated from crossover: G = [00001 00011], F = [0, -1], Score = 0.500
# 2nd child generated from crossover: G = [00010 00111], F = [1, -3], Score = 0.091
# Removing worst individual from population: G = [00010 00111], F = [1, -3], Score = 0.091
# Removing worst individual from population: G = [00001 00110], F = [0, 3], Score = 0.100
# Generation # 31 -> Average population score = 0.278
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00001 00111], F = [0, -3], Score = 0.100
# Removing worst individual from population: G = [00001 00111], F = [0, -3], Score = 0.100
# Generation # 32 -> Average population score = 0.293
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00100 00010], F = [2, 1], Score = 0.167
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00100 00010], F = [2, 1], Score = 0.167
# Removing worst individual from population: G = [00001 00111], F = [0, -3], Score = 0.100
# Removing worst individual from population: G = [00001 00110], F = [0, 3], Score = 0.100
# Generation # 33 -> Average population score = 0.303
#
# 1st parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00101 00010], F = [-2, 1], Score = 0.167
# Removing worst individual from population: G = [00100 00010], F = [2, 1], Score = 0.167
# Generation # 34 -> Average population score = 0.314
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Crossover will happen at point 7
# 1st child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00100 00010], F = [2, 1], Score = 0.167
# Removing worst individual from population: G = [00100 00010], F = [2, 1], Score = 0.167
# Generation # 35 -> Average population score = 0.326
#
# 1st parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00101 00000], F = [-2, 0], Score = 0.200
# Removing worst individual from population: G = [00101 00000], F = [-2, 0], Score = 0.200
# Generation # 36 -> Average population score = 0.334
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00101 00000], F = [-2, 0], Score = 0.200
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Generation # 37 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Generation # 38 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Generation # 39 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 3
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Generation # 40 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Generation # 41 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 4
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Generation # 42 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00010], F = [1, 1], Score = 0.333
# Generation # 43 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Generation # 44 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Crossover will happen at point 8
# 1st child generated from crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Generation # 45 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00010 00011], F = [1, -1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00011], F = [-1, -1], Score = 0.333
# Removing worst individual from population: G = [00011 00011], F = [-1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Generation # 46 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Crossover will happen at point 9
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00011 00011], F = [-1, -1], Score = 0.333
# Removing worst individual from population: G = [00010 00010], F = [1, 1], Score = 0.333
# Generation # 47 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Crossover will happen at point 2
# 1st child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00010], F = [1, 1], Score = 0.333
# Generation # 48 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 6
# 1st child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Generation # 49 -> Average population score = 0.339
#
# 1st parent chosen for crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# 2nd parent chosen for crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# Crossover will happen at point 1
# 1st child generated from crossover: G = [00011 00010], F = [-1, 1], Score = 0.333
# 2nd child generated from crossover: G = [00010 00010], F = [1, 1], Score = 0.333
# Removing worst individual from population: G = [00010 00011], F = [1, -1], Score = 0.333
# Removing worst individual from population: G = [00011 00010], F = [-1, 1], Score = 0.333
# Generation # 50 -> Average population score = 0.339
#
# Best individual: G = [00001 00011], F = [0, -1], Score = 0.500

# %% [markdown]
# ### Dado o código de Algoritmos genéticos acima, faça o que se pede:

# %% [markdown]
# #### A) Na classe Problema, altere a função objetivo para: a * x^2 + b * y^2 , onde 'a' deve ser o primeiro dígito da sua matrícula e 'b' o último digito da sua matrícula. (Caso o último número seja 0, use 1 ao invés)
# #### Ex: Se sua matrícula for 123, 'a'  será 1 e 'b' será 3, então sua função objetivo deve ser  1 * x^2 + 3 * y^2

# %% [markdown]
# @staticmethod
#    def f(x, y):
#        return 1*x**2 + 1*y**2

# %% [markdown]
# ##### B) Altere a seleção dos pais de modo a selecionar 3 pais de forma aleatória e, dentre os 3 pais selecionados, utilizar apenas os dois melhores para gerar novos filhos

# %% [markdown]
# @staticmethod
#    def selection(population):
#        parent1 = random.choice(population).max()
#        parent2 = random.choice(population).max()
#
#        print(f"1st parent chosen for crossover: {GeneticUtils.format_chromossome(parent1)}")
#        print(f"2nd parent chosen for crossover: {GeneticUtils.format_chromossome(parent2)}")
#
#        return parent1, parent2

# %% [markdown]
# ##### C) No método de crossover, da classe de Operadores Genéticos, altere a geração dos dois filhos. O filho 1 deve ter os primeiros genes do pai 2, e após o ponto de crossover, do pai 1. Enquanto o filho 2 deve ter os primeiros genes do pai 1, e após o ponto de crossover, do pai 2.

# %% [markdown]
# ## 3- PSO

# %% [markdown]
# Na implementação do algoritmo The Cornfield Vector são levados em consideração os valores de pbest, gbest e um "fator de craziness" no momento da atualização da velocidade da partícula. Altere no código abaixo os valores de w, c1 e c2, de modo que o valor do "fator de inércia" seja igual a 0.3, a influência do número aleatório r2 seja de 0.5 e a influência do número aleatório r1 seja de 0.1.

# %%
 def update_velocity(self, gbest_pos):
        '''
        Atualiza a velocidade com base em um "fator de craziness", o pbest e o gbest
        '''
        w = 0.3
        c1 = 0.2
        c2 = 0.3

        for i in range(0, self.num_dimensions):
            
            r1 = random.random(0.1)
            r2 = random.random(0.5)

            vel_cognitive = c1 * r1 * (self.pbest_pos[i] - self.position[i])
            vel_social = c2 * r2 * (gbest_pos[i] - self.position[i])

            self.velocity[i] = w * self.velocity[i] + vel_cognitive + vel_social
